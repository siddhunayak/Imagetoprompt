# %%
# !pip install clip-interrogator==0.6.0
# Out:
# Collecting clip-interrogator==0.6.0
#   Downloading clip_interrogator-0.6.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from clip-interrogator==0.6.0) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from clip-interrogator==0.6.0) (0.23.0+cu126)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from clip-interrogator==0.6.0) (11.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from clip-interrogator==0.6.0) (2.32.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from clip-interrogator==0.6.0) (0.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from clip-interrogator==0.6.0) (4.67.1)
# Collecting open-clip-torch (from clip-interrogator==0.6.0)
#   Downloading open_clip_torch-3.1.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from clip-interrogator==0.6.0) (1.10.1)
# Requirement already satisfied: transformers>=4.27.1 in /usr/local/lib/python3.12/dist-packages (from clip-interrogator==0.6.0) (4.56.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.27.1->clip-interrogator==0.6.0) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.27.1->clip-interrogator==0.6.0) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.27.1->clip-interrogator==0.6.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.27.1->clip-interrogator==0.6.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.27.1->clip-interrogator==0.6.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.27.1->clip-interrogator==0.6.0) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.27.1->clip-interrogator==0.6.0) (0.22.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->clip-interrogator==0.6.0) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip-interrogator==0.6.0) (3.4.0)
# Collecting ftfy (from open-clip-torch->clip-interrogator==0.6.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open-clip-torch->clip-interrogator==0.6.0) (1.0.19)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->clip-interrogator==0.6.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->clip-interrogator==0.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->clip-interrogator==0.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->clip-interrogator==0.6.0) (2025.8.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.27.1->clip-interrogator==0.6.0) (1.1.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->clip-interrogator==0.6.0) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open-clip-torch->clip-interrogator==0.6.0) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->clip-interrogator==0.6.0) (3.0.2)
# Downloading clip_interrogator-0.6.0-py3-none-any.whl (787 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787.8/787.8 kB 24.6 MB/s eta 0:00:00
# Downloading open_clip_torch-3.1.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 58.4 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: ftfy, open-clip-torch, clip-interrogator
# Successfully installed clip-interrogator-0.6.0 ftfy-6.3.1 open-clip-torch-3.1.0

# %%
from PIL import Image
from clip_interrogator import Config, Interrogator

# %%
image = Image.open('download.jpeg').convert('RGB')

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=170x297>

# %%
from traitlets.traitlets import Integer
ci = Interrogator(Config(clip_model_name="ViT-L-14/openai"))
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading caption model blip-large...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Loading CLIP model ViT-L-14/openai...
# open_clip_model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# ViT-L-14_openai_artists.safetensors: 100%|██████████| 16.2M/16.2M [00:00<00:00, 62.5MB/s]
# ViT-L-14_openai_flavors.safetensors: 100%|██████████| 155M/155M [00:00<00:00, 169MB/s]
# ViT-L-14_openai_mediums.safetensors: 100%|██████████| 146k/146k [00:00<00:00, 6.37MB/s]
# ViT-L-14_openai_movements.safetensors: 100%|██████████| 307k/307k [00:00<00:00, 6.64MB/s]
# ViT-L-14_openai_trendings.safetensors: 100%|██████████| 111k/111k [00:00<00:00, 7.29MB/s]
# ViT-L-14_openai_negative.safetensors: 100%|██████████| 63.2k/63.2k [00:00<00:00, 5.43MB/s]
# Loaded CLIP model and data in 26.86 seconds.

# %%
result =ci.interrogate(image)
# Out:
# /usr/local/lib/python3.12/dist-packages/clip_interrogator/clip_interrogator.py:200: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():
#   0%|          | 0/55 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/clip_interrogator/clip_interrogator.py:376: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# 100%|██████████| 55/55 [00:01<00:00, 52.40it/s]
# /usr/local/lib/python3.12/dist-packages/clip_interrogator/clip_interrogator.py:271: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():
# Flavor chain:   0%|          | 0/32 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/clip_interrogator/clip_interrogator.py:260: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():
# Flavor chain:  25%|██▌       | 8/32 [00:24<01:13,  3.06s/it]
# 100%|██████████| 55/55 [00:00<00:00, 61.01it/s]
# 100%|██████████| 6/6 [00:00<00:00, 72.47it/s]
# 100%|██████████| 50/50 [00:00<00:00, 109.68it/s]
# /usr/local/lib/python3.12/dist-packages/clip_interrogator/clip_interrogator.py:280: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():

# %%
print(result)
# Out:
# painting of a woman with long hair and a smile on her face, mona lisa as a real person, woman looks like sharon tate, amazing photorealistic graphics, by Leonardo da Vinci, imaginefx : : hyperrealism, virgin mary, with a beautifull smile
